# %% [markdown]
# # VQA-Fusion: Colab Training Runner
# Clones the repo and runs training/evaluation on Colab's GPU.

# %%
# !git clone https://github.com/GoliJyothish/vqa-fusion-gpt.git
# %cd vqa-fusion-gpt
# !pip install -r requirements.txt -q

# %%
# TODO: download/prepare CLEVR subset into data/clevr_subset/ before training
# TODO: plug your tokenizer into train.py's get_tokenizer()

# %%
# !python train.py --config configs/concat_fusion.yaml

# %%
# !python train.py --config configs/cross_attn_fusion.yaml

# %%
# !python evaluate.py --compare configs/concat_fusion.yaml configs/cross_attn_fusion.yaml
